# %% [markdown]
# # Terms extraction

# %%
import sys
sys.path.append('../terms_extraction/')

import pandas as pd
from terms_extractor import terms_extractor

pd.set_option('display.max_colwidth', None)
df = pd.read_csv('../datasets/B2W-Reviews01.csv')
df = df[['product_name']]

extract, processed_df = terms_extractor(data=df, measures=['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count'], 
                                        target_column='product_name', verbose=1)

display(processed_df)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# =============================== RUNNING THE PREPROCESSING ===============================
#
# Defined pipeline: ['transform_to_lowercase', 'remove_special_characters']
#
# Preprocess --> transform_to_lowercase
# Converting text to lowercase...
# Done!
#
# Preprocess --> remove_special_characters
# Removing special characters from text...
# Done!
#
# =============================== END OF THE PREPROCESSING ================================
#
# ============================ RUNNING THE TERMS IDENTIFICATION ===========================
#
# Performing the terms identification with ['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count'] measures...
#
# You're gonna identify 1000 terms per measure!
# ...
#
# Applying yake measure...
# Applying tfidf measure...
# ...

# %% [markdown]
# # Using limit of tokens
# * Terms will have up to the assigned number, use the hyperparameter "number_of_tokens".

# %%
import sys
sys.path.append('../terms_extraction/')

import pandas as pd
from terms_extractor import terms_extractor

df = pd.read_csv('../datasets/B2W-Reviews01.csv')
df = df[['product_name']]

extract, processed_df = terms_extractor(data=df, measures=['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count'], 
                                        target_column='product_name', number_of_tokens=3, verbose=1)

display(processed_df)
# Out:
# =============================== RUNNING THE PREPROCESSING ===============================
#
# Defined pipeline: ['transform_to_lowercase', 'remove_special_characters']
#
# Preprocess --> transform_to_lowercase
# Converting text to lowercase...
# Done!
#
# Preprocess --> remove_special_characters
# Removing special characters from text...
# Done!
#
# =============================== END OF THE PREPROCESSING ================================
#
# ============================ RUNNING THE TERMS IDENTIFICATION ===========================
#
# Performing the terms identification with ['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count'] measures...
#
# You're gonna identify 1000 terms per measure!
# ...
#
# Applying yake measure...
# Applying tfidf measure...
# Applying pmi measure...
# Applying mle measure...
# Applying dice measure...
# Applying count measure...
#
# Done!
#
# ============================ END OF THE TERMS IDENTIFICATION ============================
#
# ...

# %% [markdown]
# # Specifying number of terms to extract
# * Use the hyperparameter "number_to_extract".

# %%
import sys
sys.path.append('../terms_extraction/')

import pandas as pd
from terms_extractor import terms_extractor

df = pd.read_csv('../datasets/B2W-Reviews01.csv')
df = df[['product_name']]

extract, processed_df = terms_extractor(data=df, measures=['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count'], 
                                        target_column='product_name', number_of_tokens=3, 
                                        number_to_extract=500, verbose=1)

display(processed_df)
# Out:
# =============================== RUNNING THE PREPROCESSING ===============================
#
# Defined pipeline: ['transform_to_lowercase', 'remove_special_characters']
#
# Preprocess --> transform_to_lowercase
# Converting text to lowercase...
# Done!
#
# Preprocess --> remove_special_characters
# Removing special characters from text...
# Done!
#
# =============================== END OF THE PREPROCESSING ================================
#
# ============================ RUNNING THE TERMS IDENTIFICATION ===========================
#
# Performing the terms identification with ['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count'] measures...
#
# You're gonna identify 500 terms per measure!
#
# Applying yake measure...
# Applying tfidf measure...
# Applying pmi measure...
# Applying mle measure...
# Applying dice measure...
# Applying count measure...
#
# Done!
#
# ============================ END OF THE TERMS IDENTIFICATION ============================
#
# ...

# %% [markdown]
# # Specifying number of terms to extract by threshould
# * The hyperparameter "threshold_percentage" will define the number of terms to extract based in the number of n-grams.

# %%
import sys
sys.path.append('../terms_extraction/')

import pandas as pd
from terms_extractor import terms_extractor

df = pd.read_csv('../datasets/B2W-Reviews01.csv')
df = df[['product_name']]

extract, processed_df = terms_extractor(data=df, measures=['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count'], 
                                        target_column='product_name', number_of_tokens=3,
                                        threshold_percentage=0.995, verbose=1)

display(processed_df)
# Out:
# =============================== RUNNING THE PREPROCESSING ===============================
#
# Defined pipeline: ['transform_to_lowercase', 'remove_special_characters']
#
# Preprocess --> transform_to_lowercase
# Converting text to lowercase...
# Done!
#
# Preprocess --> remove_special_characters
# Removing special characters from text...
# Done!
#
# =============================== END OF THE PREPROCESSING ================================
#
# ============================ RUNNING THE TERMS IDENTIFICATION ===========================
#
# Performing the terms identification with ['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count'] measures...
#
# You're gonna identify 2217 terms per measure!
# ...
#
# Applying yake measure...
# Applying tfidf measure...
# Applying pmi measure...
# Applying mle measure...
# Applying dice measure...
# Applying count measure...
#
# Done!
#
# ============================ END OF THE TERMS IDENTIFICATION ============================
#
# ...

# %% [markdown]
# # Using your own list

# %%
import sys
sys.path.append('../terms_extraction/')

import pandas as pd
from terms_extractor import terms_extractor

df = pd.read_csv('../datasets/B2W-Reviews01.csv')
df = df[['product_name']]

extract=['fita led', 'painel', 'mop giratorio', 'carregador', 'notebook', 'smart tv', 'copo']

extract, processed_df = terms_extractor(data=df, extract=extract, target_column='product_name', 
                                        number_of_tokens=2, stopwords=True, language='portuguese', 
                                        verbose=1)

display(processed_df)
# Out:
# =============================== RUNNING THE PREPROCESSING ===============================
#
# Defined pipeline: ['transform_to_lowercase', 'remove_special_characters', 'remove_stopwords']
#
# Preprocess --> transform_to_lowercase
# Converting text to lowercase...
# Done!
#
# Preprocess --> remove_special_characters
# Removing special characters from text...
# Done!
#
# Preprocess --> remove_stopwords
# Getting stopword list and removing from text...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Done!
#
# =============================== END OF THE PREPROCESSING ================================
#
# ============================== RUNNING THE TERMS EXTRACTION =============================
#
# This stage can take several minutes...
#
# Terms extraction with your list...
# Processing column prep: 100%|██████████| 132289/132289 [00:00<00:00, 253766.42it/s]
# Done!
#
# ...

# %% [markdown]
# # Showing other functionalities...
# * For example, it is possible to use a list of names to identify texts that need to be anonymized.

# %%
import sys
sys.path.append('../terms_extraction/')

import pandas as pd
from terms_extractor import terms_extractor

df = pd.DataFrame(
    {'review_text': ['Meu nome é Pedro e odiei o serviço', 
                     'A atendente Márcia foi muito boa!', 
                     'Adorei a entrega']
    }
)

_, processed_df = terms_extractor(data=df, target_column='review_text', 
                                  extract=['pedro', 'marcia'], number_of_tokens=1)

display(processed_df)
# Out:
# Processing column prep: 100%|██████████| 3/3 [00:00<00:00, 17427.86it/s]
#                           review_text                                prep  \
# 0  Meu nome é Pedro e odiei o serviço  meu nome e pedro e odiei o servico
# 1   A atendente Márcia foi muito boa!    a atendente marcia foi muito boa
# 2                    Adorei a entrega                    adorei a entrega
#
#   your list
# 0   [pedro]
# 1  [marcia]
# 2        []

# %% [markdown]
# ## Just getting the list, without extracting the terms in the text

# %%
import sys
sys.path.append('../terms_extraction/')

import pandas as pd
from terms_extractor import terms_extractor

df = pd.read_csv('../datasets/B2W-Reviews01.csv')
df = df[['product_name']]

extract, _ = terms_extractor(data=df, measures=['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count'], 
                             target_column='product_name', number_to_extract=50,
                             perform_term_extraction=False, verbose=1)

print(extract)
# Out:
# =============================== RUNNING THE PREPROCESSING ===============================
#
# Defined pipeline: ['transform_to_lowercase', 'remove_special_characters']
#
# Preprocess --> transform_to_lowercase
# Converting text to lowercase...
# Done!
#
# Preprocess --> remove_special_characters
# Removing special characters from text...
# Done!
#
# =============================== END OF THE PREPROCESSING ================================
#
# ============================ RUNNING THE TERMS IDENTIFICATION ===========================
#
# Performing the terms identification with ['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count'] measures...
#
# You're gonna identify 50 terms per measure!
#
# Applying yake measure...
# Applying tfidf measure...
# Applying pmi measure...
# Applying mle measure...
# Applying dice measure...
# Applying count measure...
#
# Done!
#
# ============================ END OF THE TERMS IDENTIFICATION ============================
#
# ...

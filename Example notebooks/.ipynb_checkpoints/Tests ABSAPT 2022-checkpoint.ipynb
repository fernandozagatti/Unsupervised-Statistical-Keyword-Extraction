# %%
from huggingface_hub import login
import pandas as pd

from langchain_community.llms import HuggingFaceEndpoint
from langchain_community.llms import HuggingFaceHub
from langchain.chains import LLMChain
from langchain_core.prompts import PromptTemplate

import time

import warnings
warnings.filterwarnings("ignore")

huggingfacehub_api_token = 'add_your_api_token'

all_results = []

# %% [markdown]
# # Import dataset

# %%
import pandas as pd
import unicodedata
import re

df = pd.read_csv('../datasets/absapt_2022.csv', delimiter=';')
df = df[['review', 'aspect']]

def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    return "".join([c for c in nfkd_form if not unicodedata.combining(c)])

def remove_special_chars(input_str):
    return re.sub(r'[^a-zA-Z0-9\s]', ' ', input_str)

# Apply the function to remove accents and special characters
df['aspect'] = df['aspect'].apply(remove_accents).apply(remove_special_chars)
df = df[df['aspect'].apply(lambda x: len(x.split()) == 1)]

# Group reviews and combine aspects into a list
df = df.groupby('review')['aspect'].apply(list).reset_index()

# Transform column of lists into a single list containing all elements
all_elements = [item for sublist in df['aspect'] for item in sublist]

# Remove duplicates
unique_elements = list(set(all_elements))

#df = df.head(5)
display(df)
# Out:
# Lista de elementos únicos:
# 65
#                                                 review  \
# 0    A 4 quadras do Central Park , ótimo lugar para...
# 1    A comodidade dos quartos do hotel e a facilida...
# 2    A localização do hotel é muito boa , porém as ...
# 3    A localização é muito boa, pois fica no centro...
# 4    A única coisa que ainda passa é o café da manh...
# ..                                                 ...
# 179  Ótima localização em frente a uma estação do m...
# 180  Ótima localização, a 20 minutos aproximadament...
# 181  Ótima localização, café farto e delicioso, chu...
# 182  Ótima localização. Fica na strip, ao lado do b...
# 183  Ótimo preço e pertinho do aeroporto e com serv...
#
#                                                 aspect
# 0                             [quarto, cozinha, suite]
# 1                         [quarto, hotel, atendimento]
# 2          [atendimento, localizacao, recepcao, hotel]
# 3                    [atendimento, hotel, localizacao]
# 4                                   [quarto, chuveiro]
# ..                                                 ...
# 179           [rua, quarto, localizacao, praca, hotel]
# 180        [localizacao, hotel, cama, quarto, cozinha]
# 181  [localizacao, cama, chuveiro, atendimento, lim...
# 182                                   [estacionamento]
# 183        [preco, horario, servico, aeroporto, hotel]
#
# [184 rows x 2 columns]

# %% [markdown]
# # LLMs

# %%
llm_vlt5 = HuggingFaceHub(repo_id='Voicelab/vlt5-base-keywords', 
                          huggingfacehub_api_token=huggingfacehub_api_token,
                          model_kwargs={"max_length":500})

llm_google = HuggingFaceHub(repo_id='google/flan-t5-xxl', 
                            huggingfacehub_api_token=huggingfacehub_api_token,
                            model_kwargs={"max_length":500})

llm_bigscience = HuggingFaceEndpoint(repo_id='bigscience/bloom', 
                                     huggingfacehub_api_token=huggingfacehub_api_token,
                                     model_kwargs={"max_length":500})

llm_face = HuggingFaceHub(repo_id='facebook/blenderbot-400M-distill', 
                          huggingfacehub_api_token=huggingfacehub_api_token,
                          model_kwargs={"max_length":500, 'truncation': 'only_first'})

llm_bode = HuggingFaceHub(repo_id='recogna-nlp/Phi-Bode', 
                               huggingfacehub_api_token=huggingfacehub_api_token,
                               model_kwargs={"max_length":500})
# Out:
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Function to run the algorithms

# %%
def RunLLM(llm, df, question_text, template, llmbode=0):
    begin = time.time()
    result_list = []
    count = 0
    
    for text in df['review']:
        try: 
            question = f"{question_text} {text}"
            prompt = PromptTemplate.from_template(template)
            llm_chain = LLMChain(prompt=prompt, llm=llm)
            #print(f'{count} - Text: {text}')
            result = llm_chain.run(question)
            if (llmbode == 1):
                result_list.append(result.split('A lista é')[1])
            else:
                result_list.append(result.split('\n')[0])
            #print('-----------------------------------')
            count = count + 1
        except Exception as e:
            print(e)
            result_list.append('error')
            count = count + 1

    end = time.time()

    elapsed_time = end - begin
    print("Tempo decorrido:", elapsed_time, "segundos\n")
    
    return result_list

# %% [markdown]
# # Running algorithms

# %% [markdown]
# ## Without custom list

# %% [markdown]
# ### Getting results:

# %%
all_results_without_list = []

# %% [markdown]
# #### Phi-Bode

# %%
question_text = f"Baseado na seguinte frase, retorne uma lista das palavras mais relevantes:"           
template = """Questão: {question}
Resposta: A lista é """

all_results_without_list.append(RunLLM(llm_bode, df, question_text, template, llmbode=1))
# Out:
# Tempo decorrido: 1563.833020210266 segundos

# %% [markdown]
# #### Vlt5

# %%
question_text = f"Based in the following phrase, return a list of the most relevant words:"           
template = """Question: {question}
Answer: The list is """

all_results_without_list.append(RunLLM(llm_vlt5, df, question_text, template))
# Out:
# Tempo decorrido: 408.4122705459595 segundos
#
# []

# %% [markdown]
# #### Google

# %%
all_results_without_list.append(RunLLM(llm_google, df, question_text, template))
# Out:
# 422 Client Error: Unprocessable Entity for url: https://api-inference.huggingface.co/models/google/flan-t5-xxl (Request ID: RTR1mz44kRs99PdrL5N_W)
#
# Input validation error: `inputs` tokens + `max_new_tokens` must be <= 1024. Given: 1047 `inputs` tokens and 100 `max_new_tokens`
# Make sure 'text2text-generation' task is supported by the model.
# Tempo decorrido: 106.81346106529236 segundos

# %% [markdown]
# #### BigScience

# %%
all_results_without_list.append(RunLLM(llm_bigscience, df, question_text, template))
# Out:
# Tempo decorrido: 3561.5364277362823 segundos

# %% [markdown]
# #### Face

# %%
all_results_without_list.append(RunLLM(llm_face, df, question_text, template))
# Out:
# Tempo decorrido: 662.6539831161499 segundos

# %% [markdown]
# #### KeyBERT

# %%
import sys
sys.path.append('../terms_extraction/')

from terms_extractor import terms_extractor

from keybert import KeyBERT

inicio = time.time()

kw_model = KeyBERT()
keywords = kw_model.extract_keywords(' '.join(df['review'].tolist()), top_n=250)

keywords = [item[0] for item in keywords]

_, processed_df_keybert = terms_extractor(data=df, extract=keywords, 
                                          target_column='review', verbose=1)

fim = time.time()
tempo_decorrido = fim - inicio
print("Tempo decorrido:", tempo_decorrido, "segundos")
# Out:
# =============================== RUNNING THE PREPROCESSING ===============================
#
# Defined pipeline: ['transform_to_lowercase', 'remove_special_characters']
#
# Preprocess --> transform_to_lowercase
# Converting text to lowercase...
# Done!
#
# Preprocess --> remove_special_characters
# Removing special characters from text...
# Done!
#
# =============================== END OF THE PREPROCESSING ================================
#
# ============================== RUNNING THE TERMS EXTRACTION =============================
#
# This stage can take several minutes...
#
# Terms extraction with your list...
# Processing column prep: 100%|██████████| 184/184 [00:00<00:00, 24934.64it/s]
# Done!
#
# ============================== END OF THE TERMS EXTRACTION ==============================
#
# Tempo decorrido: 2.321974039077759 segundos

# %%
df_final = pd.read_csv('Results_without_list.csv')
df_final = df_final.drop('keybert', axis=1)
processed_df_keybert.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### USKE

# %%
import sys
sys.path.append('../terms_extraction/')

from terms_extractor import terms_extractor

inicio = time.time()

extract, processed_df = terms_extractor(data=df, measures=['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count'], 
                                        target_column='review', number_to_extract=65, 
                                        stopwords=True, language='portuguese', verbose=1)

fim = time.time()

def merge_list(row):
    merged_list = []
    for sublist in row:
        merged_list.extend(sublist)
    merged_list = list(set(merged_list))
    return merged_list

processed_df['merged'] = processed_df[['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count']].apply(merge_list, axis=1)
processed_df.reset_index(drop=True, inplace=True)

display(processed_df)

tempo_decorrido = fim - inicio
print("Tempo decorrido:", tempo_decorrido, "segundos")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# =============================== RUNNING THE PREPROCESSING ===============================
#
# Defined pipeline: ['transform_to_lowercase', 'remove_special_characters', 'remove_stopwords']
#
# Preprocess --> transform_to_lowercase
# Converting text to lowercase...
# Done!
#
# Preprocess --> remove_special_characters
# Removing special characters from text...
# Done!
#
# Preprocess --> remove_stopwords
# Getting stopword list and removing from text...
# Done!
#
# =============================== END OF THE PREPROCESSING ================================
#
# ============================ RUNNING THE TERMS IDENTIFICATION ===========================
#
# Performing the terms identification with ['yake', 'tfidf', 'pmi', 'mle', 'dice', 'count'] measures...
#
# You're gonna identify 65 terms per measure!
#
# Applying yake measure...
# Applying tfidf measure...
# Applying pmi measure...
# Applying mle measure...
# Applying dice measure...
# Applying count measure...
#
# Done!
#
# ============================ END OF THE TERMS IDENTIFICATION ============================
#
# ============================== RUNNING THE TERMS EXTRACTION =============================
#
# This stage can take several minutes...
#
# Terms extraction with yake...
# Processing column prep: 100%|██████████| 184/184 [00:00<00:00, 32827.94it/s]
# Terms extraction with tfidf...
# Processing column prep: 100%|██████████| 184/184 [00:00<00:00, 32354.50it/s]
# Terms extraction with pmi...
# Processing column prep: 100%|██████████| 184/184 [00:00<00:00, 74192.65it/s]
# Terms extraction with mle...
# Processing column prep: 100%|██████████| 184/184 [00:00<00:00, 22247.74it/s]
# Terms extraction with dice...
# Processing column prep: 100%|██████████| 184/184 [00:00<00:00, 96444.88it/s]
# Terms extraction with count...
# Processing column prep: 100%|██████████| 184/184 [00:00<00:00, 30139.50it/s]
# Done!
#
# ============================== END OF THE TERMS EXTRACTION ==============================
#                                                 review  \
# 0    A 4 quadras do Central Park , ótimo lugar para...
# 1    A comodidade dos quartos do hotel e a facilida...
# 2    A localização do hotel é muito boa , porém as ...
# 3    A localização é muito boa, pois fica no centro...
# 4    A única coisa que ainda passa é o café da manh...
# ..                                                 ...
# 179  Ótima localização em frente a uma estação do m...
# 180  Ótima localização, a 20 minutos aproximadament...
# 181  Ótima localização, café farto e delicioso, chu...
# 182  Ótima localização. Fica na strip, ao lado do b...
# 183  Ótimo preço e pertinho do aeroporto e com serv...
#
#                                                 aspect  \
# 0                             [quarto, cozinha, suite]
# 1                         [quarto, hotel, atendimento]
# 2          [atendimento, localizacao, recepcao, hotel]
# 3                    [atendimento, hotel, localizacao]
# 4                                   [quarto, chuveiro]
# ..                                                 ...
# 179           [rua, quarto, localizacao, praca, hotel]
# 180        [localizacao, hotel, cama, quarto, cozinha]
# 181  [localizacao, cama, chuveiro, atendimento, lim...
# 182                                   [estacionamento]
# 183        [preco, horario, servico, aeroporto, hotel]
#
#                                                   prep  \
# 0    4 quadras central park otimo lugar dar corrida...
# 1    comodidade quartos hotel facilidade deslocamen...
# 2    localizacao hotel boa porem partes comuns pequ...
# 3    localizacao boa pois fica centro cidade atendi...
# 4    unica coisa ainda passa cafe manha mediano qua...
# ..                                                 ...
# 179  otima localizacao frente estacao metro praca f...
# 180  otima localizacao 20 minutos aproximadamente t...
# 181  otima localizacao cafe farto delicioso chuveir...
# 182  otima localizacao fica strip lado belaggio pra...
# 183  otimo preco pertinho aeroporto servico transfe...
#
#                                                   yake  \
# 0    [otimo, perto, tudo, quartos, fica, room, tip,...
# 1    [quartos, hotel, metro, atendimento, recomendo...
# 2    [localizacao, hotel, boa, porem, diaria, recep...
# 3    [localizacao, boa, pois, fica, centro, cidade,...
# 4    [cafe, manha, quartos, pequenos, banheiro, poi...
# ..                                                 ...
# 179  [otima, localizacao, frente, estacao, metro, p...
# 180  [otima, localizacao, torre, perto, metro, hote...
# 181  [otima, localizacao, cafe, banheiro, limpo, ca...
# 182  [otima, localizacao, fica, quarto, hoteis, rec...
# 183         [otimo, preco, servico, hotel, bom, pouco]
#
#                                                  tfidf       pmi  \
# 0    [quadras, otimo, perto, tudo, quartos, amplos,...       [4]
# 1    [quartos, hotel, metro, neste, atendimento, bo...        []
# 2    [localizacao, hotel, boa, porem, cafe, atendim...       [4]
# 3    [localizacao, boa, fica, centro, atendimento, ...        []
# 4                                [cafe, quartos, tudo]        []
# ..                                                 ...       ...
# 179  [otima, localizacao, frente, estacao, metro, p...        []
# 180  [otima, localizacao, perto, metro, hotel, quar...        []
# 181  [otima, localizacao, cafe, limpo, cama, atendi...        []
# 182  [otima, localizacao, fica, strip, pra, quarto,...  [coisas]
# 183            [otimo, preco, servico, hotel, bom, lo]   [chega]
#
#                                                    mle      dice  \
# 0    [otimo, perto, tudo, quartos, fica, room, tip,...       [4]
# 1    [quartos, hotel, metro, atendimento, recomendo...        []
# 2    [localizacao, hotel, boa, porem, diaria, recep...       [4]
# 3    [localizacao, boa, pois, fica, centro, cidade,...        []
# 4         [cafe, manha, quartos, banheiro, pois, tudo]        []
# ..                                                 ...       ...
# 179  [otima, localizacao, frente, estacao, metro, p...        []
# 180  [otima, localizacao, torre, perto, metro, hote...        []
# 181  [otima, localizacao, cafe, banheiro, limpo, ca...        []
# 182  [otima, localizacao, fica, quarto, hoteis, rec...  [coisas]
# 183         [otimo, preco, servico, hotel, bom, pouco]   [chega]
#
#                                                  count  \
# 0    [otimo, perto, tudo, quartos, fica, room, tip,...
# 1    [quartos, hotel, metro, atendimento, recomendo...
# 2    [localizacao, hotel, boa, porem, diaria, recep...
# 3    [localizacao, boa, pois, fica, centro, cidade,...
# 4         [cafe, manha, quartos, banheiro, pois, tudo]
# ..                                                 ...
# 179  [otima, localizacao, frente, estacao, metro, p...
# 180  [otima, localizacao, torre, perto, metro, hote...
# 181  [otima, localizacao, cafe, banheiro, limpo, ca...
# 182  [otima, localizacao, fica, quarto, hoteis, rec...
# 183         [otimo, preco, servico, hotel, bom, pouco]
#
#                                                 merged
# 0    [otimo, tip, quartos, vista, boa, pois, amplos...
# 1    [tip, quartos, neste, limpos, bom, sempre, hot...
# 2    [cafe, recepcao, manha, boa, diaria, hotel, po...
# 3    [boa, atendimento, centro, hotel, pois, cidade...
# 4    [cafe, pequenos, quartos, manha, banheiro, poi...
# ..                                                 ...
# 179  [paris, cafe, estacao, quartos, recomendo, pro...
# 180  [cama, torre, vista, hotel, quarto, confortave...
# 181  [cafe, cama, ficamos, banheiro, limpo, atendim...
# 182  [preco, hoteis, coisas, recomendo, strip, bom,...
# 183  [servico, preco, pouco, lo, bom, hotel, chega,...
#
# [184 rows x 10 columns]
# Tempo decorrido: 0.4576995372772217 segundos

# %% [markdown]
# ### Transforming the results into CSV

# %%
df_final = pd.DataFrame(all_results_without_list).transpose()
df_final.columns = ['Bode', 'vlt5', 'Google', 'BigScience', 'Facebook']
df_final = processed_df.merge(df_final, left_index=True, right_index=True)
df_final['keybert'] = processed_df_keybert['your list']

display(df_final)

df_final.to_csv('Results_without_list.csv', index=False)
# Out:
#                                                 review  \
# 0    A 4 quadras do Central Park , ótimo lugar para...
# 1    A comodidade dos quartos do hotel e a facilida...
# 2    A localização do hotel é muito boa , porém as ...
# 3    A localização é muito boa, pois fica no centro...
# 4    A única coisa que ainda passa é o café da manh...
# ..                                                 ...
# 179  Ótima localização em frente a uma estação do m...
# 180  Ótima localização, a 20 minutos aproximadament...
# 181  Ótima localização, café farto e delicioso, chu...
# 182  Ótima localização. Fica na strip, ao lado do b...
# 183  Ótimo preço e pertinho do aeroporto e com serv...
#
#                                                 aspect  \
# 0                             [quarto, cozinha, suite]
# 1                         [quarto, hotel, atendimento]
# 2          [atendimento, localizacao, recepcao, hotel]
# 3                    [atendimento, hotel, localizacao]
# 4                                   [quarto, chuveiro]
# ..                                                 ...
# 179           [rua, quarto, localizacao, praca, hotel]
# 180        [localizacao, hotel, cama, quarto, cozinha]
# 181  [localizacao, cama, chuveiro, atendimento, lim...
# 182                                   [estacionamento]
# 183        [preco, horario, servico, aeroporto, hotel]
#
#                                                   prep  \
# 0    4 quadras central park otimo lugar dar corrida...
# 1    comodidade quartos hotel facilidade deslocamen...
# 2    localizacao hotel boa porem partes comuns pequ...
# 3    localizacao boa pois fica centro cidade atendi...
# 4    unica coisa ainda passa cafe manha mediano qua...
# ..                                                 ...
# 179  otima localizacao frente estacao metro praca f...
# 180  otima localizacao 20 minutos aproximadamente t...
# 181  otima localizacao cafe farto delicioso chuveir...
# 182  otima localizacao fica strip lado belaggio pra...
# 183  otimo preco pertinho aeroporto servico transfe...
#
#                                                   yake  \
# 0    [otimo, perto, tudo, quartos, fica, room, tip,...
# 1    [quartos, hotel, metro, atendimento, recomendo...
# 2    [localizacao, hotel, boa, porem, diaria, recep...
# 3    [localizacao, boa, pois, fica, centro, cidade,...
# 4    [cafe, manha, quartos, pequenos, banheiro, poi...
# ..                                                 ...
# 179  [otima, localizacao, frente, estacao, metro, p...
# 180  [otima, localizacao, torre, perto, metro, hote...
# 181  [otima, localizacao, cafe, banheiro, limpo, ca...
# 182  [otima, localizacao, fica, quarto, hoteis, rec...
# 183         [otimo, preco, servico, hotel, bom, pouco]
#
#                                                  tfidf       pmi  \
# 0    [quadras, otimo, perto, tudo, quartos, amplos,...       [4]
# 1    [quartos, hotel, metro, neste, atendimento, bo...        []
# 2    [localizacao, hotel, boa, porem, cafe, atendim...       [4]
# 3    [localizacao, boa, fica, centro, atendimento, ...        []
# 4                                [cafe, quartos, tudo]        []
# ..                                                 ...       ...
# 179  [otima, localizacao, frente, estacao, metro, p...        []
# 180  [otima, localizacao, perto, metro, hotel, quar...        []
# 181  [otima, localizacao, cafe, limpo, cama, atendi...        []
# 182  [otima, localizacao, fica, strip, pra, quarto,...  [coisas]
# 183            [otimo, preco, servico, hotel, bom, lo]   [chega]
#
#                                                    mle      dice  \
# 0    [otimo, perto, tudo, quartos, fica, room, tip,...       [4]
# 1    [quartos, hotel, metro, atendimento, recomendo...        []
# 2    [localizacao, hotel, boa, porem, diaria, recep...       [4]
# 3    [localizacao, boa, pois, fica, centro, cidade,...        []
# 4         [cafe, manha, quartos, banheiro, pois, tudo]        []
# ..                                                 ...       ...
# 179  [otima, localizacao, frente, estacao, metro, p...        []
# 180  [otima, localizacao, torre, perto, metro, hote...        []
# 181  [otima, localizacao, cafe, banheiro, limpo, ca...        []
# 182  [otima, localizacao, fica, quarto, hoteis, rec...  [coisas]
# 183         [otimo, preco, servico, hotel, bom, pouco]   [chega]
#
#                                                  count  \
# 0    [otimo, perto, tudo, quartos, fica, room, tip,...
# 1    [quartos, hotel, metro, atendimento, recomendo...
# 2    [localizacao, hotel, boa, porem, diaria, recep...
# 3    [localizacao, boa, pois, fica, centro, cidade,...
# 4         [cafe, manha, quartos, banheiro, pois, tudo]
# ..                                                 ...
# 179  [otima, localizacao, frente, estacao, metro, p...
# 180  [otima, localizacao, torre, perto, metro, hote...
# 181  [otima, localizacao, cafe, banheiro, limpo, ca...
# 182  [otima, localizacao, fica, quarto, hoteis, rec...
# 183         [otimo, preco, servico, hotel, bom, pouco]
#
#                                                 merged  \
# 0    [otimo, tip, quartos, vista, boa, pois, amplos...
# 1    [tip, quartos, neste, limpos, bom, sempre, hot...
# 2    [cafe, recepcao, manha, boa, diaria, hotel, po...
# 3    [boa, atendimento, centro, hotel, pois, cidade...
# 4    [cafe, pequenos, quartos, manha, banheiro, poi...
# ..                                                 ...
# 179  [paris, cafe, estacao, quartos, recomendo, pro...
# 180  [cama, torre, vista, hotel, quarto, confortave...
# 181  [cafe, cama, ficamos, banheiro, limpo, atendim...
# 182  [preco, hoteis, coisas, recomendo, strip, bom,...
# 183  [servico, preco, pouco, lo, bom, hotel, chega,...
#
#                                                   vlt5  \
# 0                  Central Park, mahattan, uma corrida
# 1    hotel, hotel, hotel, hotel, hotel, hotel, hote...
# 2    Accor, Accor, Accor, Accor, Accor, Accor, Acco...
# 3    localization, localization, localization, loca...
# 4    ainda passa, manhã mediano, quartos, quartos, ...
# ..                                                 ...
# 179  Paris, localization, localization, localizatio...
# 180  aproximadamente, localization, localization, l...
# 181  café farto, cama maravilhosa, café farto, loca...
# 182  localization, localization, localization, loca...
# 183                      aeroporto, aeroporto, taxista
#
#                                                 Google  \
# 0                        caminhar, quarto, sala, vista
# 1                               charlie, hotel, quarto
# 2                              localizacao, part, star
# 3                            cidade, localizaço, hotel
# 4                                 banho, passa, quarto
# ..                                                 ...
# 179                            localizacao, praça, rua
# 180                              eiffel, hotel, quarto
# 181  banheiro, cama, chuveiro, delicioso, farto, ch...
# 182                    localizacao, recomendo, reserva
# 183                           airport, hotel, transfer
#
#                                             BigScience  \
# 0     Central Park (4 quadras away), a good place t...
# 1     "quartos superiores" (loft), "metrô" (subway)...
# 2     : localização, hotel, pequena, comum, classif...
# 3     a very good location, since it is located in ...
# 4     pequeno, antigo, mediano, rir, fazer, fisioló...
# ..                                                 ...
# 179   'Ótima localização em frente a uma estação do...
# 180   the following words: Ótima localização, a 20 ...
# 181   ["Ótima", "localização", "café", "farto", "ch...
# 182   Ótima localização, Fica na strip, ao lado do ...
# 183   ótimo, preço, pertinho, aeroporto, serviço, t...
#
#                                               Facebook
# 0     Wow, that's a lot of quadruple quadres. Do yo...
# 1     I'm not sure what that means, but I do know t...
# 2     Do you speak any other languages? I speak Spa...
# 3     Wow, that's a lot of words. I didn't know the...
# 4     I love french cuisine, but I don't know how t...
# ..                                                 ...
# 179   I'm not sure what that means, but I do know t...
# 180   I have never been to Paris, but I would love ...
# 181   I'm not sure what you are trying to say, but ...
# 182   I don't know what tremendous umtrem is, but I...
# 183   I'm not sure what that means, but I do know t...
#
# [184 rows x 14 columns]

# %% [markdown]
# ## With custom list

# %% [markdown]
# ### Getting results:

# %%
all_results_with_list = []

# %% [markdown]
# #### Phi-Bode

# %%
question_text = f"Com base nesta lista de palavras {unique_elements}, retorne apenas as palavras que estão na seguinte frase:"           
template = """Questão: {question}
Resposta: A lista é """

all_results_with_list.append(RunLLM(llm_bode, df, question_text, template, llmbode=1))
# Out:
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: keHjl0dBHezk2ctgJFCC4)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: RIBuGxLSHkUGcObe0ygke)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: Y-Nu83Ln-hGchF6Ko64YV)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: OLV-KNTq7W_B0bihsiiqA)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: mbk4ENDmPWsE1_5qjKkEy)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: RMTBcflnoCDpXe2-29W45)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: HdpWCEcQJXRDzCAoezbQw)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: 3DEjZ_GJUGGtA4NSwfrHF)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: aNFNmopd7dsuWKw-AE5Xu)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: 7yo2APgFf-ToKvsFkj0xa)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: F0-g_fNtDC-ss6GYM6s5C)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: dBe86n3JgtE7FkmCfJzMG)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: eJF4w8jnrt0zHITXXCdCu)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: trlSkWqPNZ0WW_4UUXDX4)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: b7cjKJkwad7fYZ0vNzNbj)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: TllYTMrXaP5tTGShPR6jc)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: qfRKPZw14tUSBvxy4bg6O)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: R8FJVIUWujKXt_asOG3Gk)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: Cd7zoyhOhjRgYZH_ENvc3)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: 3Iaa7WHhrBNqf9x_CA3RD)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: GRSz6qIhROb1ZBMMWasOY)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: oPf6IA4JxlgGRHjMw3Hw6)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: uPFucQNr8BwwMPQe4SVoD)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: OZk6YuNv-PFisW6iUdGmm)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: 9HrLh-3KhZBb4RIJJC8G-)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: MmeRbibKqzjAJUE0wLXRr)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: uYg3OJAgfys3vMAN0FQPJ)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: A0x-qurEgLs_DLmk8FnY3)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: _Nx9VS_f8QiK87JLD2gC_)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: DKL6UdfhBP3blF1glpcsT)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: qM51FeM3-7OvrS2W7Fq67)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: 7uvEWa1qqbnNgIUc60v6P)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: yVi31WFTaRNlaW2bwpUpa)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: rvmL1PTjvIgV8fAVLPEB6)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: gS7fuSUs4JC_2kDPkQf0o)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: emCFonGa79HKMvNFAwEtt)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: l42cgI4lxZTqPw1lGBbPN)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: 8yepTbOmfw1a1MxmgmKEi)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: pf5EfwBUO14xZa-RZPepa)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: drtrLg9CCvSFklWvkURp-)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: D40rE3FKw0d94tDKHMjPP)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: wc0x0zolyqoa4zffrpqfz)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: fGhELJUgkhPXzB703AoeQ)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: PKE8aOrZGdzc50YMpHNBq)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: AC2Aj3e76YUSx4NnVQhH0)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: ClNCsbgsU4_OCte5itvHa)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: RBbMkvF29AQWgMl7GCyLt)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: oXKudaNBpXjBQe7sNf-QA)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: coJDch3AVo4uGmMsEK3L2)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: _ikpNrazK05FDESkg8sRC)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: wkWqChR1Q9nIrvXHEZQsF)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: 4YHfu2Py1v4lO1Jhf34ja)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: dWGbO_stlBeG_i_ivP1LA)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: fIBV7cucfk4T6gApW8oBz)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: wcUZsWZrHHkGD8DTWJ0Iz)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: K-rNX4CbT2rjdLLT00dJb)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: 1ed1kYtFototeMOKBKlsM)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: 3xV_xSxXXEtso7i6ylHkO)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: HZggUuUTCzocr3cGfHEp_)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: d0A4aWdqz-3XAi-fnJDNm)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: zsFB69cv379uouz1fAtQf)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: -tzZqjyik5XXcYSaTvdMz)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: oLyBO3zpUwt9yS43iajkH)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: VTIzYqsCYOHUf0fchd3d9)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/recogna-nlp/Phi-Bode (Request ID: 308WXj7Gy_tH7OW5Aeknl)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate
# Tempo decorrido: 3919.2031502723694 segundos

# %% [markdown]
# #### Vlt5

# %%
question_text = f"Based in this list of words {unique_elements}, return only the list of words that are in the following sentence:"           
template = """Question: {question}
Answer: The list is """

all_results_with_list.append(RunLLM(llm_vlt5, df, question_text, template))
# Out:
# /home/myuser/venv/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 0.3.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(
# /home/myuser/venv/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# 500 Server Error: Internal Server Error for url: https://api-inference.huggingface.co/models/Voicelab/vlt5-base-keywords (Request ID: -e6CYNyPPUmVXNrn77Des)
# 500 Server Error: Internal Server Error for url: https://api-inference.huggingface.co/models/Voicelab/vlt5-base-keywords (Request ID: yVxcvgs4nRvSE1XQAS8BE)
# 500 Server Error: Internal Server Error for url: https://api-inference.huggingface.co/models/Voicelab/vlt5-base-keywords (Request ID: xxE8fXATFkzxqpagWzzg7)
# Tempo decorrido: 1467.1695261001587 segundos

# %% [markdown]
# #### Google

# %%
all_results_with_list.append(RunLLM(llm_google, df, question_text, template))
# Out:
# 422 Client Error: Unprocessable Entity for url: https://api-inference.huggingface.co/models/google/flan-t5-xxl (Request ID: yqbFTN4_lfLmPeT4ebSRA)
#
# Input validation error: `inputs` tokens + `max_new_tokens` must be <= 1024. Given: 1034 `inputs` tokens and 100 `max_new_tokens`
# Make sure 'text2text-generation' task is supported by the model.
# 422 Client Error: Unprocessable Entity for url: https://api-inference.huggingface.co/models/google/flan-t5-xxl (Request ID: CgAluBOJshvcGVhknyFgE)
#
# Input validation error: `inputs` tokens + `max_new_tokens` must be <= 1024. Given: 1523 `inputs` tokens and 100 `max_new_tokens`
# Make sure 'text2text-generation' task is supported by the model.
# Tempo decorrido: 745.0241675376892 segundos

# %% [markdown]
# #### BigScience

# %%
all_results_with_list.append(RunLLM(llm_bigscience, df, question_text, template))
# Out:
# 502 Server Error: Bad Gateway for url: https://api-inference.huggingface.co/models/bigscience/bloom
# 502 Server Error: Bad Gateway for url: https://api-inference.huggingface.co/models/bigscience/bloom
# Tempo decorrido: 4537.331174135208 segundos

# %% [markdown]
# #### Face

# %%
all_results_with_list.append(RunLLM(llm_face, df, question_text, template))
# Out:
# Tempo decorrido: 595.7228946685791 segundos

# %% [markdown]
# #### USKE

# %%
import sys
sys.path.append('../terms_extraction/')

from terms_extractor import terms_extractor

inicio = time.time()

extract, processed_df = terms_extractor(data=df, extract=unique_elements, 
                                        target_column='review', verbose=1)

fim = time.time()

processed_df.reset_index(drop=True, inplace=True)

display(processed_df)

tempo_decorrido = fim - inicio
print("Tempo decorrido:", tempo_decorrido, "segundos")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# =============================== RUNNING THE PREPROCESSING ===============================
#
# Defined pipeline: ['transform_to_lowercase', 'remove_special_characters']
#
# Preprocess --> transform_to_lowercase
# Converting text to lowercase...
# Done!
#
# Preprocess --> remove_special_characters
# Removing special characters from text...
# Done!
#
# =============================== END OF THE PREPROCESSING ================================
#
# ============================== RUNNING THE TERMS EXTRACTION =============================
#
# This stage can take several minutes...
#
# Terms extraction with your list...
# Processing column prep: 100%|██████████| 184/184 [00:00<00:00, 56045.89it/s]
# Done!
#
# ============================== END OF THE TERMS EXTRACTION ==============================
#                                                 review  \
# 0    A 4 quadras do Central Park , ótimo lugar para...
# 1    A comodidade dos quartos do hotel e a facilida...
# 2    A localização do hotel é muito boa , porém as ...
# 3    A localização é muito boa, pois fica no centro...
# 4    A única coisa que ainda passa é o café da manh...
# ..                                                 ...
# 179  Ótima localização em frente a uma estação do m...
# 180  Ótima localização, a 20 minutos aproximadament...
# 181  Ótima localização, café farto e delicioso, chu...
# 182  Ótima localização. Fica na strip, ao lado do b...
# 183  Ótimo preço e pertinho do aeroporto e com serv...
#
#                                                 aspect  \
# 0                             [quarto, cozinha, suite]
# 1                         [quarto, hotel, atendimento]
# 2          [atendimento, localizacao, recepcao, hotel]
# 3                    [atendimento, hotel, localizacao]
# 4                                   [quarto, chuveiro]
# ..                                                 ...
# 179           [rua, quarto, localizacao, praca, hotel]
# 180        [localizacao, hotel, cama, quarto, cozinha]
# 181  [localizacao, cama, chuveiro, atendimento, lim...
# 182                                   [estacionamento]
# 183        [preco, horario, servico, aeroporto, hotel]
#
#                                                   prep  \
# 0    a 4 quadras do central park otimo lugar para d...
# 1    a comodidade dos quartos do hotel e a facilida...
# 2    a localizacao do hotel e muito boa porem as pa...
# 3    a localizacao e muito boa pois fica no centro ...
# 4    a unica coisa que ainda passa e o cafe da manh...
# ..                                                 ...
# 179  otima localizacao em frente a uma estacao do m...
# 180  otima localizacao a 20 minutos aproximadamente...
# 181  otima localizacao cafe farto e delicioso chuve...
# 182  otima localizacao fica na strip ao lado do bel...
# 183  otimo preco e pertinho do aeroporto e com serv...
#
#                                              your list
# 0                                     [cozinha, suite]
# 1                                 [hotel, atendimento]
# 2    [localizacao, hotel, instalacoes, recepcao, co...
# 3            [localizacao, cidade, atendimento, hotel]
# 4                                           [chuveiro]
# ..                                                 ...
# 179                        [localizacao, praca, hotel]
# 180  [localizacao, hotel, quarto, cozinha, cama, ca...
# 181  [localizacao, chuveiro, cama, limpeza, atendim...
# 182       [localizacao, estacionamento, quarto, preco]
# 183        [preco, aeroporto, servico, hotel, horario]
#
# [184 rows x 4 columns]
# Tempo decorrido: 0.0312349796295166 segundos

# %% [markdown]
# ### Transforming the results into CSV

# %%
df_final = pd.DataFrame(all_results_with_list).transpose()
df_final.columns = ['Bode', 'vlt5', 'Google', 'BigScience', 'Facebook']
df_final = processed_df.merge(df_final, left_index=True, right_index=True)

display(df_final)

df_final.to_csv('Results_with_list.csv', index=False)
# Out:
#                                                 review  \
# 0    A 4 quadras do Central Park , ótimo lugar para...
# 1    A comodidade dos quartos do hotel e a facilida...
# 2    A localização do hotel é muito boa , porém as ...
# 3    A localização é muito boa, pois fica no centro...
# 4    A única coisa que ainda passa é o café da manh...
# ..                                                 ...
# 179  Ótima localização em frente a uma estação do m...
# 180  Ótima localização, a 20 minutos aproximadament...
# 181  Ótima localização, café farto e delicioso, chu...
# 182  Ótima localização. Fica na strip, ao lado do b...
# 183  Ótimo preço e pertinho do aeroporto e com serv...
#
#                                                 aspect  \
# 0                             [quarto, cozinha, suite]
# 1                         [quarto, hotel, atendimento]
# 2          [atendimento, localizacao, recepcao, hotel]
# 3                    [atendimento, hotel, localizacao]
# 4                                   [quarto, chuveiro]
# ..                                                 ...
# 179           [rua, quarto, localizacao, praca, hotel]
# 180        [localizacao, hotel, cama, quarto, cozinha]
# 181  [localizacao, cama, chuveiro, atendimento, lim...
# 182                                   [estacionamento]
# 183        [preco, horario, servico, aeroporto, hotel]
#
#                                                   prep  \
# 0    a 4 quadras do central park otimo lugar para d...
# 1    a comodidade dos quartos do hotel e a facilida...
# 2    a localizacao do hotel e muito boa porem as pa...
# 3    a localizacao e muito boa pois fica no centro ...
# 4    a unica coisa que ainda passa e o cafe da manh...
# ..                                                 ...
# 179  otima localizacao em frente a uma estacao do m...
# 180  otima localizacao a 20 minutos aproximadamente...
# 181  otima localizacao cafe farto e delicioso chuve...
# 182  otima localizacao fica na strip ao lado do bel...
# 183  otimo preco e pertinho do aeroporto e com serv...
#
#                                              your list  \
# 0                                     [cozinha, suite]
# 1                                 [hotel, atendimento]
# 2    [localizacao, hotel, instalacoes, recepcao, co...
# 3            [localizacao, cidade, atendimento, hotel]
# 4                                           [chuveiro]
# ..                                                 ...
# 179                        [localizacao, praca, hotel]
# 180  [localizacao, hotel, quarto, cozinha, cama, ca...
# 181  [localizacao, chuveiro, cama, limpeza, atendim...
# 182       [localizacao, estacionamento, quarto, preco]
# 183        [preco, aeroporto, servico, hotel, horario]
#
#                                                   vlt5  \
# 0    Central Park, corrida, caminhada, quarto, quar...
# 1    a comodidade, hotel, hotel, hotel, hotel, hote...
# 2    Accor, Accor, hotel, hotel 4 estrelas, hotel 4...
# 3    atendimento, localização, funcionarios, funcio...
# 4    cama, café, chuveiro, chuveiro, chuveiro, chuv...
# ..                                                 ...
# 179  aeroporto, localização, quarto, quarto de hote...
# 180  aeroporto, hotel, hotel, hotel, hotel, hotel, ...
# 181  café farto, café limpo, café delicioso, café f...
# 182  information, localização, quarto, quarto, quar...
# 183  aeroporto, hotel, hotel, hotel, hotel, hotel, ...
#
#                                                 Google  \
# 0    quarto, hotel, quarto, quarto, quarto, quarto,...
# 1    comodidade, quartos, hotel, atendimento, preco...
# 2    localizacao, quarto, hotel, atendimento, preco...
# 3    localizacao, quarto, hotel, atendimento, preco...
# 4    quarto, hotel, quarto, chuveiro, jantar, escad...
# ..                                                 ...
# 179  localizacao, praça, feira, rua, praça, estaço,...
# 180  localizacao, Charles, Eiffel, quarto, vista, T...
# 181  localizacao, café, chuveiro, banheiro, cama, l...
# 182  localizacao, quarto, hotel, quarto, trem, reso...
# 183                           airport, hotel, transfer
#
#                                             BigScience  \
# 0     ['quadra', 'park', 'central', 'mesa', 'caminh...
# 1     ['comodidade', 'quartos', 'facilidade', 'desl...
# 2     ['hotel', 'localizacao', 'apartamento', 'gere...
# 3     ['localizacao', 'atendimento', 'ba', 'entrada...
# 4     ['banheiro', 'banheira', 'casal', 'chuveiro',...
# ..                                                 ...
# 179   ['cama', 'piscina', 'estacionamento', 'calefa...
# 180   ['20 minutos aproximadamente', 'aproximadamen...
# 181   ['cama', 'cafe', 'localizacao', 'banheiro', '...
# 182   ['cama', 'piscina', 'estacionamento', 'calefa...
# 183   ['cama', 'piscina', 'estacionamento', 'calefa...
#
#                                               Facebook
# 0     I'm not sure what "travail" means, but I do k...
# 1     I'm not sure what "travail" means, but I do k...
# 2     I'm not sure what "travail" means, but I do k...
# 3     I'm not sure what "travail" means, but I do k...
# 4     I'm not sure what "travail" means, but I do k...
# ..                                                 ...
# 179   I'm not sure what "travail" means, but I do k...
# 180   I'm not sure what "travail" means, but I do k...
# 181   I'm not sure what "travail" means, but I do k...
# 182   I'm not sure what "travail" means, but I do k...
# 183   I'm not sure what "travail" means, but I do k...
#
# [184 rows x 8 columns]
